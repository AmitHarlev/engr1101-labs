# %% [markdown]
# # Traveling Salesman Problem (TSP)

# %% [markdown]
# **Objectives**
#
# - Introduce students to a real-world problem solved by OR practitioners
# - Demonstrate the use of heuristics to obtain good solutions to optimization problems
# - Give students an appreciation of the difficulty of solving optimization problems exactly
#
# **Reading:** Chapter 2, The Traveling Salesman Problem.
#
# **Brief description:** Finding an optimal solution to a traveling salesman problem and proving that it is optimal are difficult tasks. In practice, when a feasible solution to a difficult problem is needed quickly, one often uses heuristics: procedures that quickly generate feasible solutions or improve existing ones and, ideally, produce good results. In this lab, we will consider several such heuristic procedures for the TSP.
#
# *TSP VLSI instances adapted from [TSPLIB](http://comopt.ifi.uni-heidelberg.de/software/TSPLIB95/) and [Bonn Institute](http://www.math.uwaterloo.ca/tsp/vlsi/index.html)*
#
#  <br>

# %% [markdown]
# ## Jupyter Notebook Introduction

# %% [markdown]
# The labs for this course will be completed in Jupyter Notebooks. Each lab will include a Jupyter Notebook (with the file extension `.ipynb`) and any other files necessary to run it, such as supplementary Python code, images, or data.
#
# In this first lab, we will begin with a brief introduction to Jupyter Notebooks. A notebook consists primarily of two types of cells: text (Markdown) cells and code cells. Until this point, the notebook has contained only Markdown cells. Markdown is a lightweight markup language that allows you to create elements such as tables and mathematical equations. Right now, you are seeing the Markdown after it has been rendered. Double-click the text `CLICK HERE` to see the Markdown source.

# %% [markdown]
# `CLICK HERE` Now that you have double-clicked, you should be able to type in this cell. Try it out:
#
#
#
# To render this text, press Ctrl+Enter. Press Shift+Enter to render it and move to the next cell.

# %% [markdown]
# ## Paired Lab Work in ENGRI 1101
#
# You will work in groups (usually of two) for each lab in ENGRI 1101. We want everyone to have an opportunity to learn and contribute. Toward that end, labs work as follows:
#  * At any given time, one member of the group is the "Driver." _Only the driver edits cells or writes answers!_
#  * All other group members must still actively read and participate in the lab, including in discussions of every lab question. _The driver does not get to answer questions or make decisions alone simply because they are the driver!_
#  * The lab will instruct you to swap drivers periodically.
#
# **Names of group members:**
#
# **Who will be "driving" for the first portion of this lab: (write their name and NetID here)**
#
# _As a reminder, only the person driving should touch the keyboard. Everyone in the group must read the lab and help answer the questions. The driver must still discuss questions and answers with the group; they cannot write down answers without discussion, even if they already know them._

# %% [markdown]
# ## Jupyter Notebook Practice

# %% [markdown]
# Here are some other cool things you can do in Markdown!
#
# - **Bold** and *italics*
# - Equations:
#     - $3x_1 + 4x_2 = 10$
#     - $\frac{2}{3} + \frac{2}{3} = \frac{4}{3}$
#     - $2^x = 4$
# - Tables:
#
# |   | 1 | 2 | 3 | 4 |
# |---|---|---|---|---|
# | a |   |   |   |   |
# | b |   |   |   |   |

# %% [markdown]
# And now for the most important type of cell in a Jupyter Notebook: the code cell! We can use a code cell to write and run Python code. Let's look at an example. As with a Markdown cell, press Ctrl+Enter to run a code cell or Shift+Enter to run it and move to the next cell.

# %%
# This is a code cell
# We use # to make a comment in a code cell
a = 7

# %% [markdown]
# The cell above creates a variable called `a` and sets its value to 7. This variable and its value carry over to other cells in the notebook. A number appears in brackets to the left of a code cell after the cell has been run. The number indicates the order in which the code cells were run. If a variable appears on the last line of a code cell, its value will be displayed below the cell.

# %%
a

# %% [markdown]
# Here are a few examples of different operations in Python.

# %%
# addition and multiplication
b = 3
c = a + b
print(c)
d = a * b
print(d)

# lists
array = [1,2,3]
print(array[1])

array # recall, since this is on the last line, its value will be printed

# %% [markdown]
# As we use Jupyter Notebooks throughout the rest of these labs, we will introduce new tools and functionality. **Note:** This course requires no previous programming experience and is not a programming course. The programming will be limited to making small changes to code and writing mathematical models.

# %% [markdown]
# ## For Loops and Summation
#
# In the first lecture, we saw an equation like $$\texttt{time}[\texttt{visit}[1], \texttt{visit}[2]]+\texttt{time}[\texttt{visit}[2], \texttt{visit}[3]]+\cdots+\texttt{time}[\texttt{visit}[n-1], \texttt{visit}[n]]+\texttt{time}[\texttt{visit}[n], \texttt{visit}[1]].$$
#
# This is a bit lengthy to write, and throughout this course, we will use summation notation to be more succinct. When we want to evaluate large sums explicitly, we'll use Python syntax that mirrors our mathematical notation.
#
# Mathematically, we use the symbol $\sum$ to denote a sum.  For example, the notation $$\sum_{i=0}^3 i^2$$ means "sum the function $i^2$ for all values of $i$ from $i=0$ to $i=3$ (including both 0 and 3)".   That is $$\sum_{i=0}^3 i^2= 0^2+1^2+2^2+3^2 = 0+1+4+9=13.$$
#
# In Python, we can use `sum` to directly add things in a list.  For instance, to compute the above sum, run the following:

# %%
answer=sum([0, 1, 4, 9])
print(answer)

# %% [markdown]
# Thus, one way to compute $\sum_{i=0}^3 i^2$ is to manually compute the individual terms ($0^2, 1^2, 2^2,$ and $3^2$), type them in a list, and ask Python to `sum` the elements of that list. This approach, however, still requires us to compute all the individual terms manually. We can make our lives easier by having Python build the list of terms. To do so, we can use `for` loops, which allow us to step through collections of data.
#
# Here, we will use a `for` loop to step through the values from $i=0$ to $i=3$, compute $i^2$ for each value, and add the results. First, we need to know how to compute powers in Python: the Python syntax for $a^b$ is `a**b`. For example, we write `3**2` to compute $3^2$:

# %%
print(3**2)

# %% [markdown]
# Now let's define a `for` loop that steps through the list `[0, 1, 2, 3]` of possible values of $i$. At each step, we create a variable named `square` that stores the value of $i^2$, and then we print this information:

# %%
for i in [0, 1, 2, 3]:
    print("i is ", i)
    square = i**2
    print("its square is ", square, "\n")

# %% [markdown]
# When we defined our `for` loop, we used the syntax `for i in [0, 1, 2, 3]:`. This syntax specifies the list through which we are iterating: in our example, `[0, 1, 2, 3]`, which comes after the keyword `in`. We also choose the name of the variable that steps through the list: in our example, `i`, which comes between the `for` and `in` keywords.
#
# To compute our actual sum, we want to build a list `[0, 1, 4, 9]` of terms to add.
#
# Run the code cell below, which computes the sum $\sum_{i=0}^3 i^2$ in a similar fashion to how we expanded it out mathematically.  The code uses a little bit of new list syntax, but we'll shortly step through exactly what's happening.

# %%
terms = []
for i in [0, 1, 2, 3]:
    print("Appending the next term we want to add, when i=", i)
    square = i**2
    terms.append(square)
    print("So far, we have built up the list ", terms, "\n")

print("We want to add the terms in the final list ", terms)
answer = sum(terms)
print("The sum is ", answer)

# %% [markdown]
# Let's trace through what just happened: we first build an empty list `terms`.  We then use a `for` loop to step through our list `[0, 1, 2, 3]` and iterate from `i=0` to `i=3`.  For each value of `i`, we compute $i^2$ and append it to the end of the list: we can see how the list `terms` grows from `[]` to `[0^2]` to `[0^2, 1^2]` to `[0^2, 1^2, 2^2]` to `[0^2, 1^2, 2^2, 3^2]`.  When we finally have a full list of all terms we want to add, we use the `sum` function to add up all terms in that list and print the answer.
#
# We can rewrite the code more succinctly by removing print statements:

# %%
terms = []
for i in [0, 1, 2, 3]:
    square = i**2
    terms.append(square)

answer = sum(terms)
print("The sum is ", answer)

# %% [markdown]
# Modify the code above so that it computes $\sum_{i=2}^{6} i^2$.

# %% [markdown]
# **At this point, please switch drivers.**
#
# **Who will be "driving" for the next portion of this lab: (write their name and NetID here)**

# %% [markdown]
# This syntax also allows us to sum over sets that are not just composed of successive integers.  For instance, suppose we wanted to compute a sum $$\sum_{i\in \{1, 2, 7\}} 2i,$$ which means "sum $2i$ for each member $i$ of the set {1, 2, 7}."  Thus $$\sum_{i\in \{1, 2, 7\}} 2i = 2(1)+2(2)+2(7)=20.$$  In Python, we can compute:

# %%
terms = []
for i in [1, 2, 7]:
    term = 2*i
    terms.append(term)

answer = sum(terms)
print("The sum is ", answer)

# %% [markdown]
# ⚡ **Key Note:** Notice that, in the above code cells, several lines are often indented under each for loop.  Indents allow Python to recognize if a line is part of the for loop (and should be run at each step through it) or should be run after the entire for loop has completed.
#
# Run the following two code cells and compare the output. The first code cell is one we have seen before. In the second, only the first line in the `for` loop is indented. As a result, we do not compute and print $i^2$ during every iteration; we compute and print it only once, after the loop has finished. At that point, `i` stores `3`, the last value it took during the loop. Remember: **Indentation matters!**

# %%
for i in [0, 1, 2, 3]:
    print("i is ", i)
    square = i**2
    print("its square is ", square, "\n")

# %%
for i in [0, 1, 2, 3]:
    print("i is ", i)
square = i**2
print("its square is ", square, "\n")

# %% [markdown]
# ### Using Range for Larger Lists
#
# Suppose we wanted to compute $$\sum_{i=0}^{100} i^2,$$ the sum of $i^2$ from $i=0$ to $i=100$. Mirroring our work above, we could use a `for` loop like `for i in [0, 1, 2, ..., 100]`. Typing out the full list of integers from 0 to 100, however, would be tedious. Happily, Python provides the `range` function for this purpose. Run the following two code cells. Notice that they do exactly the same thing!

# %%
for number in [0, 1, 2, 3, 4]:
    print(number)

# %%
for number in range(5):
    print(number)

# %% [markdown]
# ⚡ **Key Note:** Python's indexing may seem a bit unusual at first. `range(5)` goes through the first five integers starting at 0: it starts at 0 and goes up to, but does **not** include, 5.
#
# Use `range` to rewrite the following so that it computes $\sum_{i=0}^{100} i^2$.  All you have to do is replace the list in the `for i in [0, 1, 2, 3]` with the appropriate range statement.

# %%
# Replace the list below with an appropriate range.
terms = []
for i in [0, 1, 2, 3]:
    square = i**2
    terms.append(square)

answer = sum(terms)
print("The sum is ", answer)

# %% [markdown]
# If you got 328350, you've probably made a small mistake with Python's indexing, and may want to review the key note above.
#
# ### More Succinct Sums with Range
#
# For loops allow us to understand how Python might evaluate a sum term-by-term, but in practice we'll often use more succinct notation that mirrors the mathematical sum notation.  To do so, we use *list comprehension* notation and effectively build and sum the list `terms` in one foul swoop.  We won't go into much detail in list comprehensions in this course, but the syntax should start to feel a bit readable:

# %%
our_sum = sum(i**2 for i in range(4))
print(our_sum)

# %% [markdown]
# What's the syntax doing?  We create a variable `our_sum` to store the sum.  Then we tell python to take a `sum`, and we specify that sum in parenthesis with syntax `sum(SOME FUNCTION OF i for i in range(4))`.  Here `for i in range(4)` specifies that we want to iterate `i` through `range(4)`, that is through `i=0`, `i=1`, `i=2`, and `i=3`.  We are specifically asking to sum `i**2` (i.e. $i^2$) as i iterates through this range.
#
# Let's look at one more example to highlight the connection between mathematical notation and Python syntax.  Suppose we defined the function $f(x)=x^3$. Then the notation $$\sum_{x=3}^6 f(x)$$ means "sum the function $f(x)=x^3$ starting at $x=3$ and going until $x=6.$"  So: $$\sum_{x=3}^6 f(x) = f(3)+f(4)+f(5)+f(6) = 3^3+4^3+5^3+6^3.$$
#
# The Python syntax to evaluate this sum will almost exactly match our verbal interpretation "sum the function $x^3$ for starting at $x=3$ and going until $x=6.$"  Our Python syntax translation is below.  It uses `range(a, b)`, which tells Python to start at `a` and go up to (but not including) `b`.

# %%
our_sum = sum(x**3 for x in range(3, 7))
print(our_sum)

# %% [markdown]
# Compute the following sum by hand: $\sum_{i=-1}^{2} f(i)$, where $f(i)=i^2+1$. Then edit and run the cell below to check your work.

# %%
# Edit this to match the sum we're trying to compute!
our_sum = sum(x**3 for x in range(3, 7))
print(our_sum)

# %% [markdown]
# ## Part 1: Solving TSP Manually

# %%
# Imports -- make sure you run this cell!
# This cell contains multiple import statements. Each import statement gives the notebook access to pre-bundled
# Python code that provides functionality. The first import statement imports all of the Python code in the
# file tsp.py. You may open this file and examine it if you would like.

from tsp import *
import vinal as vl
import pandas as pd
from IPython.display import Image
from bokeh.io import output_notebook, show
output_notebook()

# %% [markdown]
# In lecture, you learned about the traveling salesman problem (TSP). The input to this problem is a set of cities and the distances between them. Our goal is to find a minimum-distance path that visits every city and starts and ends at the same city. We call such a path a tour.
#
# Consider the following TSP problem consisting of 23 U.S. cities. Fun fact: this instance comes from Taylor Swift's *Eras Tour*.

# %%
# This cell imports a CSV file called us_cities_23.csv. We will often import CSV files.
# The data from the CSV file is put in the variable nodes.
# Using display(), we can see the contents of this file: each city (node) and its (x, y) position.
nodes = pd.read_csv('data/us_cities_23.csv', index_col=0)
display(nodes)

# %% [markdown]
# We can use the function `vl.create_network()` to create a graph from this CSV file of nodes.

# %%
# The help command returns information about what parameters this function takes
help(vl.create_network)

# %% [markdown]
# Because we have only a DataFrame of nodes, this function generates the distances between them. The parameter `manhattan` indicates how the distances should be computed. If `manhattan` is `True`, the Manhattan distance is computed. Otherwise, the Euclidean distance is computed. For cities located at $(a,b)$ and $(c,d)$, the Manhattan distance is $|c-a| + |d-b|$ (horizontal distance plus vertical distance). The Euclidean distance is $\sqrt{(c-a)^2 + (d-b)^2}$ (straight-line distance).

# %%
# Create the graph using Euclidean distances.
G = vl.create_network(nodes, manhattan=False)

# %% [markdown]
# Now we can find a tour manually. Running the cell below will generate a visualization of the 23 cities. Click the cities one at a time to create a tour. Clicking the last unvisited city automatically completes the tour. The tour cost updates in the lower-left, and the tour appears in the lower-right. After clicking a city, do not move your mouse until the tour has updated. If the tour does not update and the tour cost is "NaN," rerun the cell below and start over.

# %%
# Reminder: Click this cell and press either CTRL+Enter or Shift+Enter to run the cell
show(vl.create_tour_plot(G, width=600, height=375, image='images/us.png'))

# %% [markdown]
# **Q1.1:** What was the smallest tour cost you found?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **At this point, please switch drivers.**
#
# **Who will be "driving" for the next portion of this lab: (write their name and NetID here)**

# %% [markdown]
# ## Part 2: TSP Heuristics

# %% [markdown]
# In this part of the lab, we will consider four different TSP heuristics. A heuristic aims to find a good feasible solution to a problem, although it is not guaranteed to find an optimal one. We will generalize the TSP from finding an optimal tour through cities to finding an optimal tour through a set of *nodes*. These nodes could represent many different things.
#
# - **Random Neighbor:** Start at a node. Randomly select an unvisited node to visit next. Continue until all nodes have been visited, then return to the start.
# - **Nearest Neighbor:** Start at a node. Visit the closest unvisited node next; if there are ties, choose one at random. Continue until all nodes have been visited, then return to the start.
# - **Nearest Insertion:** Start with a “tour” on two nodes (for example, the closest pair of nodes). Find the closest unvisited node to any node currently in the tour. Insert that node into the tour in the best position. If multiple nodes are tied for closest, choose one at random.
# - **Farthest Insertion:** Start with a “tour” on two nodes. Find the unvisited node whose smallest distance to a node already in the tour is largest. Insert that node into the tour in the best position. If multiple nodes are tied for farthest, choose one at random.
#
# In the examples below, nearest insertion begins with the neighboring nodes in the tour `[0, 1, 0]`, while farthest insertion begins with the opposite-corner nodes `[0, 47, 0]`.

# %% [markdown]
# **Q2.1:** Which heuristic do you expect to perform best? Which do you expect to perform worst?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# To compare the heuristics, we will use a simple 6-by-8 grid of nodes. The cell below creates this instance. Note that we will initially use Manhattan distance.

# %%
# G is a NetworkX graph representing the 6-by-8 grid.
G = vl.grid_instance(6, 8, manhattan=True)

# %% [markdown]
# Let's use random neighbor as a baseline for tour length. We will use the function `tsp_heuristic_plot` to see the mechanics of the algorithm. Run the cell and use the `Previous` and `Next` buttons to move through the iterations. The tour cost updates in the lower-left, and `done.` appears in the lower-right when the heuristic has finished.

# %%
show(vl.tsp_heuristic_plot(G, 'random_neighbor', i=0))

# %% [markdown]
# To view the complete tour immediately, use `random_neighbor` to run the random neighbor heuristic and `tour_plot` to plot the tour and its cost in the lower-left.

# %%
tour = vl.random_neighbor(G)
# tour is an ordered list of the nodes starting and ending at the same node
print(tour)
show(vl.tour_plot(G, tour))

# %% [markdown]
# **Q2.2:** Does this look like a good tour to you? Run it a few times and fill out the table to see what the average tour cost is.
#
# **A:**
#
# | Run | Objective value |
# | --- | --- |
# | 1 |  |
# | 2 |  |
# | 3 |  |
# | 4 |  |
# | 5 |  |
# | **Average** |  |

# %% [markdown]
# Now, let's look at the nearest neighbor heuristic.

# %%
show(vl.tsp_heuristic_plot(G, 'nearest_neighbor', i=0))

# %% [markdown]
# **Q2.3:** As you iterate through, examine the "choices" made by the algorithm at each step. What does it do well?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Use the next cell to view the complete tour right away instead of needing to click through all the nodes each time.

# %%
tour = vl.nearest_neighbor(G, i=0)
# tour is an ordered list of the nodes starting and ending at the same node
print(tour)
show(vl.tour_plot(G, tour))

# %% [markdown]
# **Q2.4:** What does it do poorly? (That is, what decisions seemed poor to you, and why were they poor decisions?)
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **Q2.5:** Run this a few times and fill out the table.
#
# **A:**
#
# | Run | Objective value |
# | --- | --- |
# | 1 |  |
# | 2 |  |
# | 3 |  |
# | 4 |  |
# | 5 |  |
# | **Average** |  |

# %% [markdown]
# **Q2.6:** Did you get the same tour every time? Why or why not?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Now, let's look at the nearest insertion heuristic, beginning with the neighboring nodes in the tour `[0, 1, 0]`.

# %%
show(vl.tsp_heuristic_plot(G, 'nearest_insertion', initial_tour=[0,1,0]))

# %% [markdown]
# Use the next cell to view the complete tour right away instead of needing to click through all the nodes each time.

# %%
tour = vl.nearest_insertion(G, initial_tour=[0,1,0])
# tour is an ordered list of the nodes starting and ending at the same node
print(tour)
show(vl.tour_plot(G, tour))

# %% [markdown]
# **Q2.7:** Run this a few times and fill out the table.
#
# **A:**
#
# | Run | Objective value |
# | --- | --- |
# | 1 |  |
# | 2 |  |
# | 3 |  |
# | 4 |  |
# | 5 |  |
# | **Average** |  |

# %% [markdown]
# **Q2.8:** How does it compare with the previous heuristics in terms of (a) average performance and (b) what it does well or poorly?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **At this point, please switch drivers.**
#
# **Who will be "driving" for the next portion of this lab: (write their name and NetID here)**

# %% [markdown]
# Now, let's look at the farthest insertion heuristic, beginning with the opposite-corner nodes in the tour `[0, 47, 0]`.

# %%
show(farthest_insertion_plot(G, initial_tour=[0,47,0]))

# %% [markdown]
# Use the next cell to view the complete tour right away instead of needing to click through all the nodes each time.

# %%
# Start with the opposite-corner nodes in the tour `[0, 47, 0]`.
tour = farthest_insertion(G, initial_tour=[0,47,0])
# tour is an ordered list of the nodes starting and ending at the same node
print(tour)
show(vl.tour_plot(G, tour))

# %% [markdown]
# **Q2.9:** Run this a few times and fill out the table.
#
# **A:**
#
# | Run | Objective value |
# | --- | --- |
# | 1 |  |
# | 2 |  |
# | 3 |  |
# | 4 |  |
# | 5 |  |
# | **Average** |  |

# %% [markdown]
# **Q2.10:** How does it compare with the previous heuristics in terms of (a) average performance and (b) what it does well or poorly?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **Q2.11:** Now that you have seen each heuristic, which do you think will do the best and which will do the worst on average?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# To check, let's run each heuristic on the 6-by-8 grid, say, 250 times and compare the averages.

# %%
n = 250
random_neighbor_total = 0
nearest_neighbor_total = 0
nearest_insertion_total = 0
farthest_insertion_total = 0
for i in range(n):
    random_neighbor_total += vl.tour_cost(G, vl.random_neighbor(G))
    nearest_neighbor_total += vl.tour_cost(G, vl.nearest_neighbor(G))
    nearest_insertion_total += vl.tour_cost(G, vl.nearest_insertion(G))
    farthest_insertion_total += vl.tour_cost(G, farthest_insertion(G))
print("Heuristic Averages:")
print("Random Neighbor: %s" % (random_neighbor_total / n))
print("Nearest Neighbor: %s" % (nearest_neighbor_total / n))
print("Nearest Insertion: %s" % (nearest_insertion_total / n))
print("Farthest Insertion: %s" % (farthest_insertion_total / n))

# %% [markdown]
# **Q2.12:** What were the results? Was this what you expected?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Now, let's look at a 9-by-9 grid using Euclidean distance. Run each of the cells below to see the heuristics on the new instance.

# %%
G = vl.grid_instance(9, 9, manhattan=False)

# %%
tour = vl.random_neighbor(G)
show(vl.tour_plot(G, tour))

# %%
# show(vl.tsp_heuristic_plot(G, 'nearest_neighbor', i=0))
tour = vl.nearest_neighbor(G, i=0)
show(vl.tour_plot(G, tour))

# %%
# show(vl.tsp_heuristic_plot(G, 'nearest_insertion', initial_tour=[0,1,0]))
tour = vl.nearest_insertion(G, initial_tour=[0,1,0])
show(vl.tour_plot(G, tour))

# %%
# show(farthest_insertion_plot(G, initial_tour=[0,80,0]))
tour = farthest_insertion(G, initial_tour=[0,80,0])
show(vl.tour_plot(G, tour))

# %% [markdown]
# **Q2.13:** For these individual runs, how did the tours compare with those on the 6-by-8 grid using Manhattan distance?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Again, let's run each heuristic numerous times and see how they compare.

# %%
n = 100
random_neighbor_total = 0
nearest_neighbor_total = 0
nearest_insertion_total = 0
farthest_insertion_total = 0
for i in range(n):
    random_neighbor_total += vl.tour_cost(G, vl.random_neighbor(G))
    nearest_neighbor_total += vl.tour_cost(G, vl.nearest_neighbor(G))
    nearest_insertion_total += vl.tour_cost(G, vl.nearest_insertion(G))
    farthest_insertion_total += vl.tour_cost(G, farthest_insertion(G))
print("Heuristic Averages:")
print("Random Neighbor: %s" % (random_neighbor_total / n))
print("Nearest Neighbor: %s" % (nearest_neighbor_total / n))
print("Nearest Insertion: %s" % (nearest_insertion_total / n))
print("Farthest Insertion: %s" % (farthest_insertion_total / n))

# %% [markdown]
# **Q2.14:** Based on the averages, how did the heuristics' relative performance compare with that on the 6-by-8 grid using Manhattan distance?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# ## Part 3: Improving Tours: 2-OPT

# %% [markdown]
# In **Part 2**, we used heuristics to create TSP tours. We can also use heuristics to improve tours we have already found. First, let's think about how we might improve a tour.

# %%
G = vl.grid_instance(4,4)
tour = [6,9,8,12,13,14,15,11,10,5,4,0,1,2,3,7,6]
show(vl.tour_plot(G, tour, width=300, height=300))

# %% [markdown]
# **Q3.1:** Look at the tour above. How might you improve this tour? How could you generalize this strategy?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# In this part, we will examine a tour-improvement heuristic called 2-OPT. 2-OPT looks for pairs of edges that can be reconnected to strictly improve the tour cost. (For a pair of edges in a tour, there is only one alternative reconnection that still produces a tour.) It continues until no further improvements can be made. Let's run 2-OPT on our example from **Q3.1**. We will use `tsp_heuristic_plot` to generate a visualization of 2-OPT. In each iteration, two edges are highlighted in solid red, and two proposed replacement edges appear as dashed red lines.

# %%
show(vl.tsp_heuristic_plot(G, '2-OPT', tour=tour, width=300, height=300))

# %% [markdown]
# Now, we will run 2-OPT after the nearest neighbor heuristic on a 5-by-5 example using Euclidean distance.

# %%
# First, we run the nearest neighbor heuristic to get an initial tour
G = vl.grid_instance(5,5, manhattan=False)
tour = vl.nearest_neighbor(G)
show(vl.tour_plot(G, tour))

# %%
show(vl.tsp_heuristic_plot(G, '2-OPT', tour=list(tour)))

# %% [markdown]
# **Q3.2:** Run 2-OPT a few times by re-running the cell above. Do you get the same result every time? Why or why not? To see more examples, get a new initial tour by rerunning both of the preceding cells in order.
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **At this point, please switch drivers.**
#
# **Who will be "driving" for the next portion of this lab: (write their name and NetID here)**

# %% [markdown]
# Let's run 2-OPT a few times on a slightly larger grid.

# %%
G = vl.grid_instance(9,9, manhattan=False)
tour = vl.nearest_neighbor(G)
show(vl.tsp_heuristic_plot(G, '2-OPT', tour=list(tour)))

# %% [markdown]
# **Q3.3:** After running 2-OPT, do you ever get a self-crossing tour? When using Euclidean distances, is this even possible? Explain why or why not.
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Let's compare the heuristics with and without 2-OPT. We will also compare them with the optimal solution, which has already been computed.

# %%
G = vl.grid_instance(6,6, manhattan=False)
tour = optimal_tour('6x6_grid')
optimal_cost = vl.tour_cost(G, tour)
show(vl.tour_plot(G, tour))

# %%
n = 50
nearest_neighbor_total = 0
nearest_insertion_total = 0
farthest_insertion_total = 0
nearest_neighbor_2_total = 0
nearest_insertion_2_total = 0
farthest_insertion_2_total = 0
for i in range(n):
    nearest_neighbor_tour = vl.nearest_neighbor(G)
    nearest_insertion_tour = vl.nearest_insertion(G)
    farthest_insertion_tour = farthest_insertion(G)

    nearest_neighbor_total += vl.tour_cost(G, nearest_neighbor_tour)
    nearest_insertion_total += vl.tour_cost(G, nearest_insertion_tour)
    farthest_insertion_total += vl.tour_cost(G, farthest_insertion_tour)

    nearest_neighbor_2_total += vl.tour_cost(G, vl.two_opt(G, list(nearest_neighbor_tour)))
    nearest_insertion_2_total += vl.tour_cost(G, vl.two_opt(G, list(nearest_insertion_tour)))
    farthest_insertion_2_total += vl.tour_cost(G, vl.two_opt(G, list(farthest_insertion_tour)))
print("Nearest Neighbor: %s" % (nearest_neighbor_total / n))
print("Nearest Neighbor + 2-OPT: %s" % (nearest_neighbor_2_total / n))
print("Nearest Insertion: %s" % (nearest_insertion_total / n))
print("Nearest Insertion + 2-OPT: %s" % (nearest_insertion_2_total / n))
print("Farthest Insertion: %s" % (farthest_insertion_total / n))
print("Farthest Insertion + 2-OPT: %s" % (farthest_insertion_2_total / n))
print("Optimal: %s" % (optimal_cost))

# %% [markdown]
# **Q3.4:** Compare each heuristic's performance before and after 2-OPT. Then compare these results with the optimal solution.
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# For fun, let's return to the 23-city U.S. example. Let's run 2-OPT on the tour you created in **Part 1**, or on a new tour if you prefer. To do this, define the tour as follows.
#
# Note: After manually creating a tour, you can copy its list from the lower-right; that list is all we need. You can also scroll up and use the tour you created earlier instead of clicking through the cities again.

# %%
G = vl.create_network(nodes, manhattan=False)
show(vl.create_tour_plot(G, width=600, height=375, image='images/us.png'))

# %% [markdown]
# Set the `tour` variable to be the tour you manually created.

# %%
# We can define a tour like this:
tour = [22,21,19,20,18,15,17,16,14,13,10,12,11,8,1,2,3,4,9,7,0,6,5,22]

# TODO: Change the above tour to be your tour.

# %% [markdown]
# Run 2-OPT!

# %%
show(vl.tsp_heuristic_plot(G, '2-OPT', tour=list(tour), width=600, height=375, image='images/us.png'))

# %% [markdown]
# **Q3.5:** Did 2-OPT improve your tour? By how much?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Now, let's look at an optimal solution!

# %%
tour = optimal_tour('us_cities_23')
show(vl.tour_plot(G, tour, width=600, height=375, image='images/us.png'))

# %% [markdown]
# **Q3.6:** Was your tour optimal before or after 2-OPT?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# ## Part 4: TSP Application: PCB Drilling

# %% [markdown]
# In the previous parts of this lab, we have considered the original application of the TSP to touring a set of cities. We also considered an arbitrary grid of nodes. In this part, we will consider a new problem to which the TSP can be applied.

# %% [markdown]
# Consider the manufacturing of printed circuit boards (PCBs). PCBs mount integrated circuits and connect them with other hardware. Here is a picture of a PCB after the hardware has been mounted.

# %%
Image("images/pcb.jpg", width=500, height=380)

# %% [markdown]
# *Taken from [Wikipedia](https://en.wikipedia.org/wiki/Printed_circuit_board)*
#
# Before the hardware can be mounted, a large number of small holes must be drilled in the board. The hardware is then mounted by placing the pins of each component in these holes. Below, you can see the small holes before the hardware is mounted.

# %%
Image("images/pcb_holes.jpg", width=444, height=250)

# %% [markdown]
# *Taken from [AiPCBA](https://www.aipcba.com/pcb/pcb-boards.html)*
#
# We are now left with an optimization problem. We have a set of holes that must be drilled in a PCB, and we must specify the order in which the drilling machine visits them. Our goal is to choose an order that minimizes the total distance the drill travels. This problem is analogous to the TSP.

# %% [markdown]
# **Q4.1:** What are the "nodes" in the PCB drilling problem?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **Q4.2:** What is the distance between two "nodes" in the PCB drilling problem? (Assume the drill can travel in a straight line from one hole to the next).
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **Q4.3:** In answering **Q4.1** and **Q4.2**, you have fully described an input to the TSP. Assume we have a way of solving the TSP. How would you interpret the solution to the TSP (a tour of the nodes) as a solution to the PCB drilling problem?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **Q4.4:** Why does the optimal TSP tour correspond to an optimal PCB drilling solution?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Let's start by looking at a small PCB drilling instance: `xqf131`.

# %%
nodes = pd.read_csv('data/xqf131.csv', index_col=0)
nodes.head() # .head() restricts the display to just show the first 5 rows.

# %%
# As before, we need to construct a graph from this DataFrame of nodes.
G = vl.create_network(nodes)

# %% [markdown]
# Let's apply some of our TSP heuristics and 2-OPT to get some good feasible solutions to this problem!

# %%
# Nearest neighbor
tour = vl.nearest_neighbor(G)
show(vl.tour_plot(G, tour))

# %%
# Improve with 2-OPT
show(vl.tsp_heuristic_plot(G, '2-OPT', tour=list(tour)))

# %%
# Nearest insertion
tour = vl.nearest_insertion(G)
show(vl.tour_plot(G, tour))

# %%
# Improve with 2-OPT
show(vl.tsp_heuristic_plot(G, '2-OPT', tour=list(tour)))

# %%
# Optimal
tour = optimal_tour('xqf131')
show(vl.tour_plot(G, tour))

# %% [markdown]
# **Q4.5:** What were the following tour costs: nearest neighbor, nearest neighbor + 2-OPT, nearest insertion, nearest insertion + 2-OPT, and optimal? Which of the four heuristic-based methods was closest to optimal?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **At this point, please switch drivers.**
#
# **Who will be "driving" for the next portion of this lab: (write their name and NetID here)**

# %% [markdown]
# Lastly, let's look at a well-cited PCB instance in the TSP literature: `pcb442`.

# %%
nodes = pd.read_csv('data/pcb442.csv', index_col=0)
G = vl.create_network(nodes)

# %%
# Farthest insertion
tour = farthest_insertion(G)
show(vl.tour_plot(G, tour))

# %%
# Optimal
tour = optimal_tour('pcb442')
show(vl.tour_plot(G, tour))

# %% [markdown]
# **Q4.6:** How much larger is the farthest-insertion objective value than the optimal objective value, both as an absolute difference and as a percentage of the optimal objective value?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# ## Part 5: TSP Application: PCB Etching

# %% [markdown]
# In this final part, we will continue to consider TSP applications in PCB manufacturing. We will introduce two additional complications.
#
# First, in **Part 4**, we ignored a crucial part of the problem: where does the drill bit start? The drill bit must start and end in the same location. It is not good enough to just provide a tour of the holes to be drilled.

# %% [markdown]
# **Q5.1:** If we consider only a tour of the holes, we omit two distances that must be traveled. What are they?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Let's assume the drill starts in the bottom-left corner at $(0,0)$ and that all holes to be drilled are at positions $(x,y)$ for $x,y > 0$.

# %% [markdown]
# **Q5.2:** How can we adjust our TSP input to account for this? (Hint: How does the set of nodes change, and what are the distances between them?)
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# If you look back at `pcb442`, you can see that the bottom-left node represents the drill's starting location, rather than a hole that needs to be drilled.

# %% [markdown]
# Let's add the final complication. Suppose that, instead of drilling holes, we need to make a series of etchings on a board. Each etching has a starting location and an ending location. Once the etching machine arrives at a starting location, it must complete that etching and move immediately to the corresponding ending location. Below is an example of an etching instance. The bottom-left node represents the starting location for the etching machine. Each etching segment has a blue start location and a red end location.

# %%
nodes = pd.read_csv('data/xqf131_etching.csv', index_col=0)
G = create_etching_network(nodes)
show(etching_tour_plot(G, [], width=600))

# %% [markdown]
# **Q5.3:** What are the "nodes" in the PCB etching problem? (Hint: Don't forget the starting location of the etching machine.)
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# *Ask a TA if you are struggling with **Q5.3**. Once you get that, the next questions will become clearer!*

# %% [markdown]
# **Q5.4:** What is the distance between two "nodes" in the PCB etching problem? (Assume the etching machine can travel in a straight line between two locations.)
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# **Q5.5:** Our past TSP examples have been *symmetric* in that the distance from node $i$ to node $j$ was the same as the distance from node $j$ to node $i$. Is the TSP input for a PCB etching problem symmetric? Why or why not?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# Again, we can use the TSP to solve this new problem. Let's start by applying some of our TSP heuristics. When plotting a solution, dashed lines indicate when the etching machine moves between etchings.

# %%
# Nearest neighbor
show(etching_tour_plot(G, vl.nearest_neighbor(G), width=600))

# %%
# Nearest insertion
show(etching_tour_plot(G, vl.nearest_insertion(G), width=600))

# %%
# Farthest insertion
show(etching_tour_plot(G, farthest_insertion(G, initial_tour=[0,70,0]), width=600))

# %% [markdown]
# Let's see how these solutions compare to the optimal tour!

# %%
# Optimal
# The stored tour was computed using the reverse arc convention, so reverse it here.
tour = list(reversed(optimal_tour('xqf131_etching')))
show(etching_tour_plot(G, tour, width=600))

# %% [markdown]
# **Q5.6:** Compare the heuristics' performance. How did they compare with the optimal solution?
#
# **A:**
#
# _Write your answer here._

# %% [markdown]
# You may have noticed that we did not use 2-OPT to try and improve the tours. In fact, 2-OPT only applies when the distances are symmetric. In **Q5.5**, you should have found that is not the case for the PCB etching problem.

# %% [markdown]
# **Bonus:** Why does 2-OPT only apply when the distances are symmetric?
#
# **A:**
